# %%
# !pip install swig
# !pip install gymnasium[box2d]
# Out:
# Collecting swig
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.0 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.1.1
# Collecting gymnasium[box2d]
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[box2d])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 40.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.5.2)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.1.1)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2373074 sha256=5a4cad9d3e24645f6f041fdbf1a109914d4abd7a1c0433533bff0f9ac03d468b
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: farama-notifications, box2d-py, gymnasium
# Successfully installed box2d-py-2.3.5 farama-notifications-0.0.4 gymnasium-0.29.1

# %% [markdown]
# Add files the following files to local folder (volatile disk) in order to run the python program with the auxilar files:
#
# 1. DDPG.py
# 2. ActorCriticNetworks.py
# 3. ReplayBuffer.py
# 4. Noise.py
# 5. helper.py

# %%
# !python DDPG.py
# Out:
# ^C
# Timestep:  86 / 500000  Episode reward:  -148.0 Episode:  0 Mean R -147.54257716792958
#
# Timestep:  151 / 500000  Episode reward:  -674.0 Episode:  1 Mean R -410.5345858726656
#
# Timestep:  267 / 500000  Episode reward:  -1114.0 Episode:  2 Mean R -645.0644218160818
#
# Timestep:  324 / 500000  Episode reward:  -306.0 Episode:  3 Mean R -560.2825133870409
#
# Timestep:  403 / 500000  Episode reward:  -588.0 Episode:  4 Mean R -565.751269188292
#
# Timestep:  533 / 500000  Episode reward:  -115.0 Episode:  5 Mean R -490.55119732174967
#
# Timestep:  594 / 500000  Episode reward:  -102.0 Episode:  6 Mean R -435.047434049648
#
# Timestep:  649 / 500000  Episode reward:  -102.0 Episode:  7 Mean R -393.4090469454059
#
# Timestep:  721 / 500000  Episode reward:  -328.0 Episode:  8 Mean R -386.1434975601666
#
# Timestep:  810 / 500000  Episode reward:  -548.0 Episode:  9 Mean R -402.3121375022295
#
# Timestep:  905 / 500000  Episode reward:  -247.0 Episode:  10 Mean R -388.1710282178852
#
# Timestep:  981 / 500000  Episode reward:  -179.0 Episode:  11 Mean R -370.7688460739769
#
# Timestep:  1055 / 500000  Episode reward:  -127.0 Episode:  12 Mean R -352.02337137353453
#
# Timestep:  1152 / 500000  Episode reward:  -184.0 Episode:  13 Mean R -339.9939884602604
#
# Timestep:  1249 / 500000  Episode reward:  -198.0 Episode:  14 Mean R -330.50873509158765
#
# Timestep:  1429 / 500000  Episode reward:  -233.0 Episode:  15 Mean R -324.44488699636247
#
# Timestep:  1632 / 500000  Episode reward:  -195.0 Episode:  16 Mean R -316.83158071216883
#
# Timestep:  1763 / 500000  Episode reward:  -73.0 Episode:  17 Mean R -303.3082172685408
#
# Timestep:  1866 / 500000  Episode reward:  -529.0 Episode:  18 Mean R -315.2080023256859
#
# Timestep:  1973 / 500000  Episode reward:  -130.0 Episode:  19 Mean R -305.92526402909147
#
# Timestep:  2124 / 500000  Episode reward:  -120.0 Episode:  20 Mean R -297.0676666720886
#
# Timestep:  2218 / 500000  Episode reward:  -17.0 Episode:  21 Mean R -284.35887972062125
#
# Timestep:  2290 / 500000  Episode reward:  -415.0 Episode:  22 Mean R -290.06065841456467
#
# Timestep:  2421 / 500000  Episode reward:  -441.0 Episode:  23 Mean R -296.3631339847987
#
# Timestep:  2590 / 500000  Episode reward:  -80.0 Episode:  24 Mean R -287.7213865682654
#
# Timestep:  2719 / 500000  Episode reward:  -694.0 Episode:  25 Mean R -303.3662250914471
#
# Timestep:  2818 / 500000  Episode reward:  -231.0 Episode:  26 Mean R -300.67913263072484
#
# Timestep:  2899 / 500000  Episode reward:  -257.0 Episode:  27 Mean R -299.1046265497998
#
# Timestep:  2971 / 500000  Episode reward:  -733.0 Episode:  28 Mean R -314.06761596444517
#
# Timestep:  3050 / 500000  Episode reward:  -159.0 Episode:  29 Mean R -308.9032416380162
#
# Timestep:  3130 / 500000  Episode reward:  -215.0 Episode:  30 Mean R -305.87714710500586
#
# Timestep:  3209 / 500000  Episode reward:  -261.0 Episode:  31 Mean R -304.4655789993627
#
# Timestep:  3280 / 500000  Episode reward:  -315.0 Episode:  32 Mean R -304.7849175993728
#
# Timestep:  3350 / 500000  Episode reward:  -450.0 Episode:  33 Mean R -309.04852929594625
#
# Timestep:  3427 / 500000  Episode reward:  -165.0 Episode:  34 Mean R -304.9308542813078
#
# Timestep:  3518 / 500000  Episode reward:  -315.0 Episode:  35 Mean R -305.2003418191059
#
# Timestep:  3606 / 500000  Episode reward:  -406.0 Episode:  36 Mean R -307.9179639909536
#
# Timestep:  3687 / 500000  Episode reward:  -118.0 Episode:  37 Mean R -302.92180047938524
#
# Timestep:  3790 / 500000  Episode reward:  -299.0 Episode:  38 Mean R -302.81460123437705
#
# Timestep:  3894 / 500000  Episode reward:  -264.0 Episode:  39 Mean R -301.85457688923333
#
# Timestep:  4005 / 500000  Episode reward:  -183.0 Episode:  40 Mean R -298.9582884494567
#
# Timestep:  4105 / 500000  Episode reward:  -193.0 Episode:  41 Mean R -296.42681687195056
#
# Timestep:  4188 / 500000  Episode reward:  -241.0 Episode:  42 Mean R -295.1356380187073
#
# Timestep:  4351 / 500000  Episode reward:  -263.0 Episode:  43 Mean R -294.4115490467556
#
# Timestep:  4618 / 500000  Episode reward:  -341.0 Episode:  44 Mean R -295.4423920858157
#
# Timestep:  4763 / 500000  Episode reward:  -405.0 Episode:  45 Mean R -297.81933130601743
#
# Timestep:  5214 / 500000  Episode reward:  -77.0 Episode:  46 Mean R -293.1311282863224
#
# Timestep:  5402 / 500000  Episode reward:  -177.0 Episode:  47 Mean R -290.7146527133687
#
# Timestep:  5650 / 500000  Episode reward:  -250.0 Episode:  48 Mean R -289.88452125990307
#
# Timestep:  5754 / 500000  Episode reward:  -217.0 Episode:  49 Mean R -288.4284210445276
#
# Timestep:  5911 / 500000  Episode reward:  -673.0 Episode:  50 Mean R -295.9667856488398
#
# Timestep:  6059 / 500000  Episode reward:  -153.0 Episode:  51 Mean R -293.20874473870697
#
# Timestep:  6135 / 500000  Episode reward:  -215.0 Episode:  52 Mean R -291.73657600561154
#
# Timestep:  6327 / 500000  Episode reward:  -393.0 Episode:  53 Mean R -293.61487485727315
#
# Timestep:  6452 / 500000  Episode reward:  -240.0 Episode:  54 Mean R -292.6359777459651
#
# Timestep:  6578 / 500000  Episode reward:  -119.0 Episode:  55 Mean R -289.52684398453715
#
# Timestep:  6676 / 500000  Episode reward:  -381.0 Episode:  56 Mean R -291.1323475526322
#
# Timestep:  6794 / 500000  Episode reward:  -206.0 Episode:  57 Mean R -289.6725898334435
#
# Timestep:  6903 / 500000  Episode reward:  -253.0 Episode:  58 Mean R -289.0511538619781
#
# Timestep:  7005 / 500000  Episode reward:  -182.0 Episode:  59 Mean R -287.2680615497115
#
# Timestep:  7149 / 500000  Episode reward:  -285.0 Episode:  60 Mean R -287.23465034760136
#
# Timestep:  7254 / 500000  Episode reward:  -339.0 Episode:  61 Mean R -288.0676293094796
#
# Timestep:  7363 / 500000  Episode reward:  -236.0 Episode:  62 Mean R -287.2394360104304
#
# Timestep:  7501 / 500000  Episode reward:  -208.0 Episode:  63 Mean R -286.0022907528793
#
# Timestep:  7704 / 500000  Episode reward:  -417.0 Episode:  64 Mean R -288.0132036168755
#
# Timestep:  7935 / 500000  Episode reward:  -520.0 Episode:  65 Mean R -291.53225004791886
#
# Timestep:  8142 / 500000  Episode reward:  -253.0 Episode:  66 Mean R -290.95571229066474
#
# Timestep:  8305 / 500000  Episode reward:  -234.0 Episode:  67 Mean R -290.11927194639816
#
# Timestep:  8425 / 500000  Episode reward:  -198.0 Episode:  68 Mean R -288.78557862811766
#
# Timestep:  8658 / 500000  Episode reward:  -201.0 Episode:  69 Mean R -287.534319198888
#
# Timestep:  8761 / 500000  Episode reward:  -265.0 Episode:  70 Mean R -287.2217623857417
#
# Timestep:  9162 / 500000  Episode reward:  -299.0 Episode:  71 Mean R -287.3873313791238
#
# Timestep:  9246 / 500000  Episode reward:  -79.0 Episode:  72 Mean R -284.5319814997563
#
# Timestep:  9357 / 500000  Episode reward:  -305.0 Episode:  73 Mean R -284.80776465462907
#
# Timestep:  9602 / 500000  Episode reward:  -316.0 Episode:  74 Mean R -285.2299404378796
#
# Timestep:  9702 / 500000  Episode reward:  -149.0 Episode:  75 Mean R -283.4402153080676
#
# Timestep:  9848 / 500000  Episode reward:  -292.0 Episode:  76 Mean R -283.55158497249664
#
# Timestep:  9933 / 500000  Episode reward:  -287.0 Episode:  77 Mean R -283.6020553303396
#
# Timestep:  10040 / 500000  Episode reward:  -198.0 Episode:  78 Mean R -282.51821613646246
#
# Timestep:  10130 / 500000  Episode reward:  -152.0 Episode:  79 Mean R -280.89137518790807
#
# Timestep:  10216 / 500000  Episode reward:  -171.0 Episode:  80 Mean R -279.53285156098764
#
# Timestep:  10334 / 500000  Episode reward:  -520.0 Episode:  81 Mean R -282.465848117732
#
# Timestep:  10429 / 500000  Episode reward:  -263.0 Episode:  82 Mean R -282.22775703659045
#
# Timestep:  10543 / 500000  Episode reward:  -363.0 Episode:  83 Mean R -283.1895545968239
#
# Timestep:  10789 / 500000  Episode reward:  -117.0 Episode:  84 Mean R -281.23936766996144
#
# Timestep:  10930 / 500000  Episode reward:  -264.0 Episode:  85 Mean R -281.03381811802086
#
# Timestep:  11134 / 500000  Episode reward:  -264.0 Episode:  86 Mean R -280.8405273093445
#
# Timestep:  11289 / 500000  Episode reward:  -142.0 Episode:  87 Mean R -279.2627274182089
#
# Timestep:  11413 / 500000  Episode reward:  -360.0 Episode:  88 Mean R -280.1697251056103
#
# Timestep:  11498 / 500000  Episode reward:  -277.0 Episode:  89 Mean R -280.13984434275955
#
# Timestep:  11605 / 500000  Episode reward:  -240.0 Episode:  90 Mean R -279.7039077173044
#
# Timestep:  11714 / 500000  Episode reward:  -169.0 Episode:  91 Mean R -278.49559789131
#
# Timestep:  11819 / 500000  Episode reward:  -176.0 Episode:  92 Mean R -277.39647409534587
#
# Timestep:  11911 / 500000  Episode reward:  -202.0 Episode:  93 Mean R -276.5949008010943
#
# Timestep:  12026 / 500000  Episode reward:  -209.0 Episode:  94 Mean R -275.8846287178913
#
# Timestep:  12136 / 500000  Episode reward:  -389.0 Episode:  95 Mean R -277.0663990290835
#
# Timestep:  12234 / 500000  Episode reward:  -188.0 Episode:  96 Mean R -276.1466377430653
#
# Timestep:  12313 / 500000  Episode reward:  -187.0 Episode:  97 Mean R -275.23538743279636
#
# Timestep:  12563 / 500000  Episode reward:  7.0 Episode:  98 Mean R -272.3826532137151
#
# Timestep:  12692 / 500000  Episode reward:  -176.0 Episode:  99 Mean R -271.4235282253095
#
# Timestep:  12867 / 500000  Episode reward:  -265.0 Episode:  100 Mean R -272.60137598635566
#
# Timestep:  12968 / 500000  Episode reward:  -196.0 Episode:  101 Mean R -267.8261756541962
#
# Timestep:  13062 / 500000  Episode reward:  -132.0 Episode:  102 Mean R -258.00522739886026
#
# Timestep:  13178 / 500000  Episode reward:  -199.0 Episode:  103 Mean R -256.93946856349623
#
# Timestep:  13303 / 500000  Episode reward:  -166.0 Episode:  104 Mean R -252.7205588764611
#
# Timestep:  13413 / 500000  Episode reward:  -345.0 Episode:  105 Mean R -255.02951574879702
#
# Timestep:  13539 / 500000  Episode reward:  -325.0 Episode:  106 Mean R -257.26321873695036
#
# Timestep:  13700 / 500000  Episode reward:  -248.0 Episode:  107 Mean R -258.7245647481366
#
# Timestep:  13929 / 500000  Episode reward:  -279.0 Episode:  108 Mean R -258.2372750304571
#
# Timestep:  14075 / 500000  Episode reward:  -432.0 Episode:  109 Mean R -257.08237717771846
#
# Timestep:  14142 / 500000  Episode reward:  -304.0 Episode:  110 Mean R -257.6508628971097
#
# Timestep:  14297 / 500000  Episode reward:  -309.0 Episode:  111 Mean R -258.9474798533594
#
# Timestep:  14430 / 500000  Episode reward:  -163.0 Episode:  112 Mean R -259.307342593595
#
# Timestep:  14512 / 500000  Episode reward:  -460.0 Episode:  113 Mean R -262.0681158066404
#
# Timestep:  14609 / 500000  Episode reward:  -283.0 Episode:  114 Mean R -262.92488029508405
#
# Timestep:  14696 / 500000  Episode reward:  -251.0 Episode:  115 Mean R -263.09701656164316
#
# Timestep:  14793 / 500000  Episode reward:  -207.0 Episode:  116 Mean R -263.2159480068493
#
# Timestep:  14883 / 500000  Episode reward:  -273.0 Episode:  117 Mean R -265.20874169039405
#
# Timestep:  14982 / 500000  Episode reward:  -412.0 Episode:  118 Mean R -264.03796879185194
#
# Timestep:  15085 / 500000  Episode reward:  -463.0 Episode:  119 Mean R -267.36823152449904
#
# Timestep:  15315 / 500000  Episode reward:  -303.0 Episode:  120 Mean R -269.19630479249
#
# Timestep:  15451 / 500000  Episode reward:  -263.0 Episode:  121 Mean R -271.6540385843953
#
# Timestep:  15554 / 500000  Episode reward:  -338.0 Episode:  122 Mean R -270.88274247943895
#
# Timestep:  15687 / 500000  Episode reward:  -248.0 Episode:  123 Mean R -268.94788192527545
#
# Timestep:  15898 / 500000  Episode reward:  -364.0 Episode:  124 Mean R -271.78927307449146
#
# Timestep:  16073 / 500000  Episode reward:  -245.0 Episode:  125 Mean R -267.28994541646006
#
# Timestep:  16185 / 500000  Episode reward:  -186.0 Episode:  126 Mean R -266.84598108834365
#
# Timestep:  16330 / 500000  Episode reward:  -335.0 Episode:  127 Mean R -267.62652115110734
#
# Timestep:  16455 / 500000  Episode reward:  -148.0 Episode:  128 Mean R -261.7741223437144
#
# Timestep:  16611 / 500000  Episode reward:  -292.0 Episode:  129 Mean R -263.1011936135551
#
# Timestep:  16688 / 500000  Episode reward:  -266.0 Episode:  130 Mean R -263.6143876329297
#
# Timestep:  16965 / 500000  Episode reward:  -278.0 Episode:  131 Mean R -263.79066632240443
#
# Timestep:  17047 / 500000  Episode reward:  -293.0 Episode:  132 Mean R -263.5681711213098
#
# Timestep:  17159 / 500000  Episode reward:  -216.0 Episode:  133 Mean R -261.22959287156124
#
# Timestep:  17686 / 500000  Episode reward:  -380.0 Episode:  134 Mean R -263.38325666384264
#
# Timestep:  17867 / 500000  Episode reward:  -420.0 Episode:  135 Mean R -264.4357109229494
#
# Timestep:  18168 / 500000  Episode reward:  -180.0 Episode:  136 Mean R -262.1796469348099
#
# Timestep:  18292 / 500000  Episode reward:  -214.0 Episode:  137 Mean R -263.13674622771293
#
# Timestep:  18554 / 500000  Episode reward:  -367.0 Episode:  138 Mean R -263.8227676416537
#
# Timestep:  18640 / 500000  Episode reward:  -550.0 Episode:  139 Mean R -266.6786710664563
#
# Timestep:  18852 / 500000  Episode reward:  -371.0 Episode:  140 Mean R -268.56006897133585
#
# Timestep:  19081 / 500000  Episode reward:  -206.0 Episode:  141 Mean R -268.6914622595274
#
# Timestep:  19264 / 500000  Episode reward:  -230.0 Episode:  142 Mean R -268.58356230439483
#
# Timestep:  19367 / 500000  Episode reward:  -218.0 Episode:  143 Mean R -268.13282885040076
#
# Timestep:  19501 / 500000  Episode reward:  -166.0 Episode:  144 Mean R -266.3870868000752
#
# Timestep:  19643 / 500000  Episode reward:  -274.0 Episode:  145 Mean R -265.0757670332945
#
# Timestep:  19794 / 500000  Episode reward:  -538.0 Episode:  146 Mean R -269.6800318867353
#
# Timestep:  20098 / 500000  Episode reward:  -304.0 Episode:  147 Mean R -270.9533330077564
#
# Timestep:  20193 / 500000  Episode reward:  -329.0 Episode:  148 Mean R -271.74193359265337
#
# Timestep:  20284 / 500000  Episode reward:  -465.0 Episode:  149 Mean R -274.21631466434565
#
# Timestep:  20372 / 500000  Episode reward:  -267.0 Episode:  150 Mean R -270.15890766479896
#
# Timestep:  20468 / 500000  Episode reward:  -391.0 Episode:  151 Mean R -272.538500700898
#
# Timestep:  20612 / 500000  Episode reward:  -357.0 Episode:  152 Mean R -273.9580922435188
#
# Timestep:  20699 / 500000  Episode reward:  -362.0 Episode:  153 Mean R -273.64831357508285
#
# Timestep:  20847 / 500000  Episode reward:  -191.0 Episode:  154 Mean R -273.1588383416981
#
# Timestep:  21046 / 500000  Episode reward:  -329.0 Episode:  155 Mean R -275.2608611118076
#
# Timestep:  21542 / 500000  Episode reward:  -276.0 Episode:  156 Mean R -274.2060220300902
#
# Timestep:  21770 / 500000  Episode reward:  -239.0 Episode:  157 Mean R -274.5291699024917
#
# Timestep:  21874 / 500000  Episode reward:  -227.0 Episode:  158 Mean R -274.27118611450084
#
# Timestep:  22114 / 500000  Episode reward:  -387.0 Episode:  159 Mean R -276.3228106455958
#
# Timestep:  22319 / 500000  Episode reward:  -161.0 Episode:  160 Mean R -275.08272269608364
#
# Timestep:  22921 / 500000  Episode reward:  -302.0 Episode:  161 Mean R -274.71067314922874
#
# Timestep:  23078 / 500000  Episode reward:  -191.0 Episode:  162 Mean R -274.2655780177965
#
# Timestep:  23168 / 500000  Episode reward:  -455.0 Episode:  163 Mean R -276.7350260962411
#
# Timestep:  23280 / 500000  Episode reward:  -181.0 Episode:  164 Mean R -274.3756971306924
#
# Timestep:  23383 / 500000  Episode reward:  -134.0 Episode:  165 Mean R -270.5176097764022
#
# Timestep:  23509 / 500000  Episode reward:  -250.0 Episode:  166 Mean R -270.48665642718134
#
# Timestep:  23635 / 500000  Episode reward:  -514.0 Episode:  167 Mean R -273.28733544907254
#
# Timestep:  23804 / 500000  Episode reward:  -190.0 Episode:  168 Mean R -273.2036070486405
#
# Timestep:  23941 / 500000  Episode reward:  -412.0 Episode:  169 Mean R -275.31611523090896
#
# Timestep:  24231 / 500000  Episode reward:  2.0 Episode:  170 Mean R -272.64549402750293
#
# Timestep:  24335 / 500000  Episode reward:  -314.0 Episode:  171 Mean R -272.79552513578585
#
# Timestep:  24486 / 500000  Episode reward:  -107.0 Episode:  172 Mean R -273.07678727060016
#
# Timestep:  24575 / 500000  Episode reward:  -313.0 Episode:  173 Mean R -273.15939453827355
#
# Timestep:  24668 / 500000  Episode reward:  -771.0 Episode:  174 Mean R -277.70699147150947
#
# Timestep:  24737 / 500000  Episode reward:  -369.0 Episode:  175 Mean R -279.9078254904344
#
# Timestep:  24864 / 500000  Episode reward:  -548.0 Episode:  176 Mean R -282.46727215815326
#
# Timestep:  24983 / 500000  Episode reward:  -151.0 Episode:  177 Mean R -281.1023578746365
#
# Timestep:  25189 / 500000  Episode reward:  -245.0 Episode:  178 Mean R -281.57374748525046
#
# Timestep:  25326 / 500000  Episode reward:  -328.0 Episode:  179 Mean R -283.3265730298979
#
# Timestep:  25448 / 500000  Episode reward:  -422.0 Episode:  180 Mean R -285.84224387742785
#
# Timestep:  25692 / 500000  Episode reward:  -351.0 Episode:  181 Mean R -284.14847343154634
#
# Timestep:  25894 / 500000  Episode reward:  -295.0 Episode:  182 Mean R -284.4741941112766
#
# Timestep:  26034 / 500000  Episode reward:  -356.0 Episode:  183 Mean R -284.4003523356843
#
# Timestep:  26207 / 500000  Episode reward:  -253.0 Episode:  184 Mean R -285.75992471181286
#
# Timestep:  26450 / 500000  Episode reward:  -269.0 Episode:  185 Mean R -285.8168969164717
#
# Timestep:  26627 / 500000  Episode reward:  -401.0 Episode:  186 Mean R -287.1812718347961
#
# Timestep:  26770 / 500000  Episode reward:  -257.0 Episode:  187 Mean R -288.32695892448874
#
# Timestep:  26891 / 500000  Episode reward:  -354.0 Episode:  188 Mean R -288.2700355169012
#
# Timestep:  26977 / 500000  Episode reward:  -130.0 Episode:  189 Mean R -286.7966853768272
#
# Timestep:  27093 / 500000  Episode reward:  -290.0 Episode:  190 Mean R -287.2882443358798
#
# Timestep:  27267 / 500000  Episode reward:  -226.0 Episode:  191 Mean R -287.8641370088888
#
# Timestep:  27460 / 500000  Episode reward:  -337.0 Episode:  192 Mean R -289.4682333989093
#
# Timestep:  27543 / 500000  Episode reward:  -120.0 Episode:  193 Mean R -288.65179000801095
#
# Timestep:  27683 / 500000  Episode reward:  -215.0 Episode:  194 Mean R -288.7149871220703
#
# Timestep:  27759 / 500000  Episode reward:  -246.0 Episode:  195 Mean R -287.2769430713957
#
# Timestep:  27926 / 500000  Episode reward:  -238.0 Episode:  196 Mean R -287.7782862571926
#
# Timestep:  28121 / 500000  Episode reward:  -274.0 Episode:  197 Mean R -288.65107662712023
#
# Timestep:  28282 / 500000  Episode reward:  -359.0 Episode:  198 Mean R -292.31163035486367
#
# Timestep:  28419 / 500000  Episode reward:  -186.0 Episode:  199 Mean R -292.402254890897
#
# Timestep:  28591 / 500000  Episode reward:  -29.0 Episode:  200 Mean R -290.0428666031304
#
# Timestep:  29020 / 500000  Episode reward:  -377.0 Episode:  201 Mean R -291.85592125228476
#
# Timestep:  29137 / 500000  Episode reward:  -241.0 Episode:  202 Mean R -292.94161408078924
#
# Timestep:  29416 / 500000  Episode reward:  -148.0 Episode:  203 Mean R -292.4237544974873
#
# Timestep:  29641 / 500000  Episode reward:  -229.0 Episode:  204 Mean R -293.0586802222876
#
# Timestep:  29738 / 500000  Episode reward:  -233.0 Episode:  205 Mean R -291.931450848321
#
# Timestep:  29879 / 500000  Episode reward:  -207.0 Episode:  206 Mean R -290.7434667614986
#
# Timestep:  29997 / 500000  Episode reward:  -193.0 Episode:  207 Mean R -290.1959227503098
#
# Timestep:  30108 / 500000  Episode reward:  -348.0 Episode:  208 Mean R -290.8834463297968
#
# Timestep:  30227 / 500000  Episode reward:  -268.0 Episode:  209 Mean R -289.24041175084517
#
# Timestep:  30359 / 500000  Episode reward:  -204.0 Episode:  210 Mean R -288.2394043859847
#
# Timestep:  30519 / 500000  Episode reward:  -125.0 Episode:  211 Mean R -286.4040545897006
#
# Timestep:  30593 / 500000  Episode reward:  -216.0 Episode:  212 Mean R -286.93057711226777
#
# Timestep:  30739 / 500000  Episode reward:  -7.0 Episode:  213 Mean R -282.4015532094832
#
# Timestep:  30889 / 500000  Episode reward:  -207.0 Episode:  214 Mean R -281.6371294766959
#
# Timestep:  30988 / 500000  Episode reward:  -208.0 Episode:  215 Mean R -281.2112653229782
#
# Timestep:  31049 / 500000  Episode reward:  -369.0 Episode:  216 Mean R -282.8361989216655
#
# Timestep:  31153 / 500000  Episode reward:  -326.0 Episode:  217 Mean R -283.3692697722492
#
# Timestep:  31218 / 500000  Episode reward:  -187.0 Episode:  218 Mean R -281.1170051158774
#
# Timestep:  31323 / 500000  Episode reward:  -202.0 Episode:  219 Mean R -278.5087010965425
#
# Timestep:  31416 / 500000  Episode reward:  -435.0 Episode:  220 Mean R -279.8316853441705
#
# Timestep:  31494 / 500000  Episode reward:  -142.0 Episode:  221 Mean R -278.62278391509705
#
# Timestep:  31573 / 500000  Episode reward:  -243.0 Episode:  222 Mean R -277.67226158879873
#
# Timestep:  31739 / 500000  Episode reward:  -125.0 Episode:  223 Mean R -276.43950885740344
#
# Timestep:  31836 / 500000  Episode reward:  -206.0 Episode:  224 Mean R -274.85292693999475
#
# Timestep:  31956 / 500000  Episode reward:  -167.0 Episode:  225 Mean R -274.07603701499824
#
# Timestep:  32049 / 500000  Episode reward:  -313.0 Episode:  226 Mean R -275.33884732511166
#
# Timestep:  32140 / 500000  Episode reward:  -425.0 Episode:  227 Mean R -276.2452638934134
#
# Timestep:  32239 / 500000  Episode reward:  -247.0 Episode:  228 Mean R -277.24027901612806
#
# Timestep:  32467 / 500000  Episode reward:  -414.0 Episode:  229 Mean R -278.4601559119411
#
# Timestep:  32568 / 500000  Episode reward:  -166.0 Episode:  230 Mean R -277.45200161578725
#
# Timestep:  32689 / 500000  Episode reward:  -60.0 Episode:  231 Mean R -275.26597464339096
#
# Timestep:  32807 / 500000  Episode reward:  -192.0 Episode:  232 Mean R -274.254420261489
#
# Timestep:  32878 / 500000  Episode reward:  -182.0 Episode:  233 Mean R -273.91642788232264
#
# Timestep:  32992 / 500000  Episode reward:  -226.0 Episode:  234 Mean R -272.3749884715077
#
# Timestep:  33111 / 500000  Episode reward:  -183.0 Episode:  235 Mean R -270.0095812486229
#
# Timestep:  33234 / 500000  Episode reward:  -304.0 Episode:  236 Mean R -271.2463049964659
#
# Timestep:  33362 / 500000  Episode reward:  -219.0 Episode:  237 Mean R -271.29931668590575
#
# Timestep:  33605 / 500000  Episode reward:  -282.0 Episode:  238 Mean R -270.44734415552267
#
# Timestep:  33783 / 500000  Episode reward:  -161.0 Episode:  239 Mean R -266.5619814431804
#
# Timestep:  34044 / 500000  Episode reward:  -95.0 Episode:  240 Mean R -263.8029848008903
#
# Timestep:  34130 / 500000  Episode reward:  -408.0 Episode:  241 Mean R -265.82290065171907
#
# Timestep:  34305 / 500000  Episode reward:  -542.0 Episode:  242 Mean R -268.93942515817037
#
# Timestep:  34403 / 500000  Episode reward:  -111.0 Episode:  243 Mean R -267.8689939491025
#
# Timestep:  34527 / 500000  Episode reward:  -261.0 Episode:  244 Mean R -268.8179186138659
#
# Timestep:  34617 / 500000  Episode reward:  -302.0 Episode:  245 Mean R -269.10151422051985
#
# Timestep:  34748 / 500000  Episode reward:  -241.0 Episode:  246 Mean R -266.1304473509553
#
# Timestep:  34856 / 500000  Episode reward:  -199.0 Episode:  247 Mean R -265.0788474399322
#
# Timestep:  35004 / 500000  Episode reward:  -235.0 Episode:  248 Mean R -264.13924751769355
#
# Timestep:  35356 / 500000  Episode reward:  -318.0 Episode:  249 Mean R -262.6708892213071
#
# Timestep:  35536 / 500000  Episode reward:  -38.0 Episode:  250 Mean R -260.3810387070292
#
# Timestep:  35719 / 500000  Episode reward:  -18.0 Episode:  251 Mean R -256.66032539911794
#
# Timestep:  35876 / 500000  Episode reward:  -58.0 Episode:  252 Mean R -253.67082664379706
#
# Timestep:  36167 / 500000  Episode reward:  -201.0 Episode:  253 Mean R -252.05721773133575
#
# Timestep:  36289 / 500000  Episode reward:  -470.0 Episode:  254 Mean R -254.84942541567787
#
# Timestep:  36385 / 500000  Episode reward:  -88.0 Episode:  255 Mean R -252.43902749391353
#
# Timestep:  36565 / 500000  Episode reward:  -397.0 Episode:  256 Mean R -253.65295734964764
#
# Timestep:  36658 / 500000  Episode reward:  -262.0 Episode:  257 Mean R -253.88189705522902
#
# Timestep:  36805 / 500000  Episode reward:  -153.0 Episode:  258 Mean R -253.14172541120502
#
# Timestep:  36924 / 500000  Episode reward:  -486.0 Episode:  259 Mean R -254.13015559069083
#
# Timestep:  37036 / 500000  Episode reward:  -183.0 Episode:  260 Mean R -254.34753013542485
#
# Timestep:  37312 / 500000  Episode reward:  -259.0 Episode:  261 Mean R -253.92129748429778
#
# Timestep:  37477 / 500000  Episode reward:  -304.0 Episode:  262 Mean R -255.04602862425466
#
# Timestep:  37591 / 500000  Episode reward:  -252.0 Episode:  263 Mean R -253.0124201846203
#
# Timestep:  37706 / 500000  Episode reward:  -250.0 Episode:  264 Mean R -253.70273522837178
#
# Timestep:  37855 / 500000  Episode reward:  -129.0 Episode:  265 Mean R -253.64977053663833
#
# Timestep:  38054 / 500000  Episode reward:  -285.0 Episode:  266 Mean R -254.0045750760185
#
# Timestep:  38438 / 500000  Episode reward:  -307.0 Episode:  267 Mean R -251.93056806072812
#
# Timestep:  38581 / 500000  Episode reward:  -224.0 Episode:  268 Mean R -252.27619217054797
#
# Timestep:  38693 / 500000  Episode reward:  -234.0 Episode:  269 Mean R -250.4941496906913
#
# Timestep:  38797 / 500000  Episode reward:  -275.0 Episode:  270 Mean R -253.25741226438183
#
# Timestep:  38912 / 500000  Episode reward:  -355.0 Episode:  271 Mean R -253.6672980740078
#
# Timestep:  39056 / 500000  Episode reward:  -278.0 Episode:  272 Mean R -255.37935985589945
#
# Timestep:  39210 / 500000  Episode reward:  -218.0 Episode:  273 Mean R -254.42523056457708
#
# Timestep:  39335 / 500000  Episode reward:  -952.0 Episode:  274 Mean R -256.237671722057
#
# Timestep:  39527 / 500000  Episode reward:  -500.0 Episode:  275 Mean R -257.541852840701
#
# Timestep:  39808 / 500000  Episode reward:  -126.0 Episode:  276 Mean R -253.3174034140783
#
# Timestep:  40079 / 500000  Episode reward:  -256.0 Episode:  277 Mean R -254.3639138623861
#
# Timestep:  40174 / 500000  Episode reward:  -422.0 Episode:  278 Mean R -256.13541362746594
#
# Timestep:  40378 / 500000  Episode reward:  -177.0 Episode:  279 Mean R -254.62723098884646
#
# Timestep:  40544 / 500000  Episode reward:  -345.0 Episode:  280 Mean R -253.85235886448888
#
# Timestep:  40638 / 500000  Episode reward:  -229.0 Episode:  281 Mean R -252.6394958797477
#
# Timestep:  40786 / 500000  Episode reward:  -217.0 Episode:  282 Mean R -251.85283727183057
#
# Timestep:  41264 / 500000  Episode reward:  -461.0 Episode:  283 Mean R -252.90356608926078
#
# Timestep:  41382 / 500000  Episode reward:  -141.0 Episode:  284 Mean R -251.7824636301054
#
# Timestep:  41445 / 500000  Episode reward:  -192.0 Episode:  285 Mean R -251.00901243505376
#
# Timestep:  41591 / 500000  Episode reward:  -298.0 Episode:  286 Mean R -249.983842982272
#
# Timestep:  41888 / 500000  Episode reward:  -294.0 Episode:  287 Mean R -250.35999627490938
#
# Timestep:  42097 / 500000  Episode reward:  -287.0 Episode:  288 Mean R -249.69084271192466
#
# Timestep:  42353 / 500000  Episode reward:  -323.0 Episode:  289 Mean R -251.6144552884633
#
# Timestep:  42566 / 500000  Episode reward:  -522.0 Episode:  290 Mean R -253.93920917197792
#
# Timestep:  42817 / 500000  Episode reward:  -401.0 Episode:  291 Mean R -255.68814732839945
#
# Timestep:  43050 / 500000  Episode reward:  -135.0 Episode:  292 Mean R -253.66785364751024
#
# Timestep:  43433 / 500000  Episode reward:  -222.0 Episode:  293 Mean R -254.6851516621941
#
# Timestep:  43614 / 500000  Episode reward:  -153.0 Episode:  294 Mean R -254.0619307604506
#
# Timestep:  43798 / 500000  Episode reward:  -191.0 Episode:  295 Mean R -253.51214327560882
#
# Timestep:  43904 / 500000  Episode reward:  10.0 Episode:  296 Mean R -251.0343022439981
#
# Timestep:  44010 / 500000  Episode reward:  -138.0 Episode:  297 Mean R -249.67790493905278
#
# Timestep:  44157 / 500000  Episode reward:  -303.0 Episode:  298 Mean R -249.11432609829365
#
# Timestep:  44357 / 500000  Episode reward:  -417.0 Episode:  299 Mean R -251.4301751200869
#
# Timestep:  44513 / 500000  Episode reward:  -388.0 Episode:  300 Mean R -255.0201862298057
#
# Timestep:  44629 / 500000  Episode reward:  -616.0 Episode:  301 Mean R -257.4081699149061
#
# Timestep:  44749 / 500000  Episode reward:  -677.0 Episode:  302 Mean R -261.77399463015155
#
# Timestep:  44962 / 500000  Episode reward:  -154.0 Episode:  303 Mean R -261.84311233497533
#
# Timestep:  45096 / 500000  Episode reward:  -421.0 Episode:  304 Mean R -263.758694187137
#
# Timestep:  45181 / 500000  Episode reward:  -526.0 Episode:  305 Mean R -266.69184761006824
#
# Timestep:  45319 / 500000  Episode reward:  -686.0 Episode:  306 Mean R -271.48906075283946
#
# Timestep:  45465 / 500000  Episode reward:  -219.0 Episode:  307 Mean R -271.74819243489287
#
# Timestep:  45759 / 500000  Episode reward:  -327.0 Episode:  308 Mean R -271.5346907563779
#
# Timestep:  45878 / 500000  Episode reward:  -458.0 Episode:  309 Mean R -273.43724098226687
#
# Timestep:  45940 / 500000  Episode reward:  -475.0 Episode:  310 Mean R -276.15026620661257
#
# Timestep:  46194 / 500000  Episode reward:  -261.0 Episode:  311 Mean R -277.50279968577973
#
# Timestep:  46430 / 500000  Episode reward:  -547.0 Episode:  312 Mean R -280.81092060403944
#
# Timestep:  46704 / 500000  Episode reward:  -244.0 Episode:  313 Mean R -283.18020001316995
#
# Timestep:  47222 / 500000  Episode reward:  -275.0 Episode:  314 Mean R -283.8605986563697
#
# Timestep:  47403 / 500000  Episode reward:  -264.0 Episode:  315 Mean R -284.4197869564659
#
# Timestep:  47540 / 500000  Episode reward:  -317.0 Episode:  316 Mean R -283.8913707300498
#
# Timestep:  47704 / 500000  Episode reward:  -222.0 Episode:  317 Mean R -282.8548248366311
#
# Timestep:  47823 / 500000  Episode reward:  -119.0 Episode:  318 Mean R -282.17042434525763
#
# Timestep:  47919 / 500000  Episode reward:  -219.0 Episode:  319 Mean R -282.34477388488745
#
# Timestep:  48182 / 500000  Episode reward:  -162.0 Episode:  320 Mean R -279.6174472455135
#
# Timestep:  48458 / 500000  Episode reward:  -171.0 Episode:  321 Mean R -279.90661293412614
#
# Timestep:  48882 / 500000  Episode reward:  -228.0 Episode:  322 Mean R -279.7542663325041
#
# Timestep:  49047 / 500000  Episode reward:  -192.0 Episode:  323 Mean R -280.4318694111378
#
# Timestep:  49209 / 500000  Episode reward:  -184.0 Episode:  324 Mean R -280.2093452304635
#
# Timestep:  49276 / 500000  Episode reward:  -347.0 Episode:  325 Mean R -282.00721693627946
#
# Timestep:  49411 / 500000  Episode reward:  -229.0 Episode:  326 Mean R -281.17428115685476
#
# Timestep:  49508 / 500000  Episode reward:  -113.0 Episode:  327 Mean R -278.0545063696507
#
# Timestep:  49607 / 500000  Episode reward:  -292.0 Episode:  328 Mean R -278.50387584420764
#
# Timestep:  49770 / 500000  Episode reward:  -448.0 Episode:  329 Mean R -278.8425096016813
#
# Timestep:  49857 / 500000  Episode reward:  -363.0 Episode:  330 Mean R -280.8172206198593
#
# Timestep:  49965 / 500000  Episode reward:  -273.0 Episode:  331 Mean R -282.94701009867396
#
# Timestep:  50057 / 500000  Episode reward:  -290.0 Episode:  332 Mean R -283.9260706257569
#
# Timestep:  50154 / 500000  Episode reward:  -467.0 Episode:  333 Mean R -286.7708850502623
#
# Timestep:  50333 / 500000  Episode reward:  -262.0 Episode:  334 Mean R -287.1333784635637
#
# Timestep:  50578 / 500000  Episode reward:  -673.0 Episode:  335 Mean R -292.0275737588698
#
# Timestep:  50689 / 500000  Episode reward:  -318.0 Episode:  336 Mean R -292.1741730446552
#
# Timestep:  50782 / 500000  Episode reward:  -399.0 Episode:  337 Mean R -293.97031862600466
#
# Timestep:  50868 / 500000  Episode reward:  -301.0 Episode:  338 Mean R -294.159401551691
#
# Timestep:  51005 / 500000  Episode reward:  -576.0 Episode:  339 Mean R -298.30717262442306
#
# Timestep:  51106 / 500000  Episode reward:  -110.0 Episode:  340 Mean R -298.45637501966695
#
# Timestep:  51203 / 500000  Episode reward:  -232.0 Episode:  341 Mean R -296.694645259479
#
# Timestep:  51449 / 500000  Episode reward:  -255.0 Episode:  342 Mean R -293.8283193697089
#
# Timestep:  51658 / 500000  Episode reward:  -187.0 Episode:  343 Mean R -294.5914147086171
#
# Timestep:  51803 / 500000  Episode reward:  -270.0 Episode:  344 Mean R -294.6772675786031
#
# Timestep:  51900 / 500000  Episode reward:  -265.0 Episode:  345 Mean R -294.31068450548884
#
# Timestep:  52016 / 500000  Episode reward:  -270.0 Episode:  346 Mean R -294.600510863471
#
# Timestep:  52086 / 500000  Episode reward:  -358.0 Episode:  347 Mean R -296.18984414242743
#
# Timestep:  52187 / 500000  Episode reward:  -299.0 Episode:  348 Mean R -296.8290914447484
#
# Timestep:  52289 / 500000  Episode reward:  -304.0 Episode:  349 Mean R -296.68949481152
#
# Timestep:  52408 / 500000  Episode reward:  -116.0 Episode:  350 Mean R -297.4660741476302
#
# Timestep:  52563 / 500000  Episode reward:  -309.0 Episode:  351 Mean R -300.3734902710132
#
# Timestep:  52668 / 500000  Episode reward:  -319.0 Episode:  352 Mean R -302.9781584767495
#
# Timestep:  52787 / 500000  Episode reward:  -407.0 Episode:  353 Mean R -305.04386169847055
#
# Timestep:  53137 / 500000  Episode reward:  -302.0 Episode:  354 Mean R -303.35932412123793
#
# Timestep:  53320 / 500000  Episode reward:  -162.0 Episode:  355 Mean R -304.09916856138625
#
# Timestep:  53627 / 500000  Episode reward:  -160.0 Episode:  356 Mean R -301.7273281555183
#
# Timestep:  53886 / 500000  Episode reward:  -293.0 Episode:  357 Mean R -302.0433308316765
#
# Timestep:  53974 / 500000  Episode reward:  -437.0 Episode:  358 Mean R -304.8833772462356
#
# Timestep:  54062 / 500000  Episode reward:  -275.0 Episode:  359 Mean R -302.774134808801
#
# Timestep:  54273 / 500000  Episode reward:  -550.0 Episode:  360 Mean R -306.43971615767873
#
# Timestep:  54403 / 500000  Episode reward:  -495.0 Episode:  361 Mean R -308.8041057234984
#
# Timestep:  54633 / 500000  Episode reward:  -158.0 Episode:  362 Mean R -307.3496692816547
#
# Timestep:  54864 / 500000  Episode reward:  -214.0 Episode:  363 Mean R -306.977470888364
#
# Timestep:  54947 / 500000  Episode reward:  -330.0 Episode:  364 Mean R -307.7786036499946
#
# Timestep:  55120 / 500000  Episode reward:  -279.0 Episode:  365 Mean R -309.27948301717277
#
# Timestep:  55205 / 500000  Episode reward:  -345.0 Episode:  366 Mean R -309.87185382464827
#
# Timestep:  55428 / 500000  Episode reward:  -240.0 Episode:  367 Mean R -309.20766962338604
#
# Timestep:  55578 / 500000  Episode reward:  -186.0 Episode:  368 Mean R -308.82114373317336
#
# Timestep:  55674 / 500000  Episode reward:  -606.0 Episode:  369 Mean R -312.54166987574973
#
# Timestep:  55786 / 500000  Episode reward:  -449.0 Episode:  370 Mean R -314.28657701206276
#
# Timestep:  55941 / 500000  Episode reward:  -471.0 Episode:  371 Mean R -315.4417934214812
#
# Timestep:  56063 / 500000  Episode reward:  -241.0 Episode:  372 Mean R -315.06525868719183
#
# Timestep:  56159 / 500000  Episode reward:  -300.0 Episode:  373 Mean R -315.8910326065802
#
# Timestep:  56245 / 500000  Episode reward:  -252.0 Episode:  374 Mean R -308.886589424339
#
# Timestep:  56501 / 500000  Episode reward:  -290.0 Episode:  375 Mean R -306.7920216453448
#
# Timestep:  56609 / 500000  Episode reward:  -160.0 Episode:  376 Mean R -307.13635418488576
#
# Timestep:  56779 / 500000  Episode reward:  -303.0 Episode:  377 Mean R -307.6133362406716
#
# Timestep:  56913 / 500000  Episode reward:  -256.0 Episode:  378 Mean R -305.95006862861044
#
# Timestep:  57049 / 500000  Episode reward:  -204.0 Episode:  379 Mean R -306.2200243034225
#
# Timestep:  57185 / 500000  Episode reward:  -216.0 Episode:  380 Mean R -304.9292178932896
#
# Timestep:  57274 / 500000  Episode reward:  -129.0 Episode:  381 Mean R -303.92058174097286
#
# Timestep:  57422 / 500000  Episode reward:  -380.0 Episode:  382 Mean R -305.55427660608274
#
# Timestep:  57698 / 500000  Episode reward:  -281.0 Episode:  383 Mean R -303.7525004568055
#
# Timestep:  57924 / 500000  Episode reward:  -353.0 Episode:  384 Mean R -305.86490071591413
#
# Timestep:  58059 / 500000  Episode reward:  -263.0 Episode:  385 Mean R -306.5801762076128
#
# Timestep:  58525 / 500000  Episode reward:  -280.0 Episode:  386 Mean R -306.3938726988676
#
# Timestep:  58694 / 500000  Episode reward:  -396.0 Episode:  387 Mean R -307.41087234351767
#
# Timestep:  58897 / 500000  Episode reward:  -206.0 Episode:  388 Mean R -306.59928885540353
#
# Timestep:  59112 / 500000  Episode reward:  -340.0 Episode:  389 Mean R -306.7784768125535
#
# Timestep:  59272 / 500000  Episode reward:  -540.0 Episode:  390 Mean R -306.9618148054414
#
# Timestep:  59403 / 500000  Episode reward:  -169.0 Episode:  391 Mean R -304.6417328274587
#
# Timestep:  59539 / 500000  Episode reward:  -210.0 Episode:  392 Mean R -305.39231921053187
#
# Timestep:  59683 / 500000  Episode reward:  -197.0 Episode:  393 Mean R -305.1413631420215
#
# Timestep:  59844 / 500000  Episode reward:  -516.0 Episode:  394 Mean R -308.7699750522863
#
# Timestep:  59952 / 500000  Episode reward:  -193.0 Episode:  395 Mean R -308.79002697234665
#
# Timestep:  60074 / 500000  Episode reward:  -385.0 Episode:  396 Mean R -312.7378279039938
#
# Timestep:  60277 / 500000  Episode reward:  -113.0 Episode:  397 Mean R -312.47970662625943
#
# Timestep:  60410 / 500000  Episode reward:  -179.0 Episode:  398 Mean R -311.24398930063575
#
# Timestep:  60504 / 500000  Episode reward:  -230.0 Episode:  399 Mean R -309.37729540964557
#
# Timestep:  60664 / 500000  Episode reward:  -117.0 Episode:  400 Mean R -306.65914550572785
#
# Timestep:  60787 / 500000  Episode reward:  -367.0 Episode:  401 Mean R -304.1727507278318
#
# Timestep:  60899 / 500000  Episode reward:  -155.0 Episode:  402 Mean R -298.9512623125784
#
# Timestep:  61138 / 500000  Episode reward:  -173.0 Episode:  403 Mean R -299.1362695422829
#
# Timestep:  61238 / 500000  Episode reward:  -258.0 Episode:  404 Mean R -297.5089450363462
#
# Timestep:  61347 / 500000  Episode reward:  -260.0 Episode:  405 Mean R -294.84954018999105
#
# Timestep:  61442 / 500000  Episode reward:  -69.0 Episode:  406 Mean R -288.67567911830344
#
# Timestep:  61528 / 500000  Episode reward:  -240.0 Episode:  407 Mean R -288.8830743637355
#
# Timestep:  61766 / 500000  Episode reward:  -469.0 Episode:  408 Mean R -290.30528415726565
#
# Timestep:  62028 / 500000  Episode reward:  -161.0 Episode:  409 Mean R -287.3278252229795
#
# Timestep:  62224 / 500000  Episode reward:  -275.0 Episode:  410 Mean R -285.3306170626866
#
# Timestep:  62442 / 500000  Episode reward:  -307.0 Episode:  411 Mean R -285.79193337861756
#
# Timestep:  62543 / 500000  Episode reward:  -284.0 Episode:  412 Mean R -283.16697454836964
#
# Timestep:  62632 / 500000  Episode reward:  -66.0 Episode:  413 Mean R -281.38864556340127
#
# Timestep:  62760 / 500000  Episode reward:  -197.0 Episode:  414 Mean R -280.60494791653144
#
# Timestep:  62862 / 500000  Episode reward:  -253.0 Episode:  415 Mean R -280.49379820349435
#
# Timestep:  62994 / 500000  Episode reward:  -508.0 Episode:  416 Mean R -282.4118351203496
#
# Timestep:  63111 / 500000  Episode reward:  -172.0 Episode:  417 Mean R -281.91093676708203
#
# Timestep:  63227 / 500000  Episode reward:  -608.0 Episode:  418 Mean R -286.8014730290613
#
# Timestep:  63527 / 500000  Episode reward:  -217.0 Episode:  419 Mean R -286.78283792787266
#
# Timestep:  63718 / 500000  Episode reward:  -113.0 Episode:  420 Mean R -286.28940046319786
#
# Timestep:  63825 / 500000  Episode reward:  -437.0 Episode:  421 Mean R -288.9503160516144
#
# Timestep:  64290 / 500000  Episode reward:  -110.0 Episode:  422 Mean R -287.77248309564186
#
# Timestep:  64537 / 500000  Episode reward:  -347.0 Episode:  423 Mean R -289.3240951294683
#
# Timestep:  64715 / 500000  Episode reward:  -365.0 Episode:  424 Mean R -291.13544015561564
#
# Timestep:  64955 / 500000  Episode reward:  -180.0 Episode:  425 Mean R -289.47387769443174
#
# Timestep:  65143 / 500000  Episode reward:  -639.0 Episode:  426 Mean R -293.56642556257054
#
# Timestep:  65379 / 500000  Episode reward:  -452.0 Episode:  427 Mean R -296.94853776950765
#
# Timestep:  65489 / 500000  Episode reward:  -206.0 Episode:  428 Mean R -296.0836720083174
#
# Timestep:  65765 / 500000  Episode reward:  -398.0 Episode:  429 Mean R -295.5833397980221
#
# Timestep:  65992 / 500000  Episode reward:  -167.0 Episode:  430 Mean R -293.6177461240592
#
# Timestep:  66215 / 500000  Episode reward:  -245.0 Episode:  431 Mean R -293.33992826313784
#
# Timestep:  66335 / 500000  Episode reward:  -325.0 Episode:  432 Mean R -293.6997289784065
#
# Timestep:  66490 / 500000  Episode reward:  -57.0 Episode:  433 Mean R -289.6076822170704
#
# Timestep:  66593 / 500000  Episode reward:  -111.0 Episode:  434 Mean R -288.0911192906349
#
# Timestep:  66846 / 500000  Episode reward:  -206.0 Episode:  435 Mean R -283.42816575688283
#
# Timestep:  67080 / 500000  Episode reward:  -6.0 Episode:  436 Mean R -280.2991276042714
#
# Timestep:  67175 / 500000  Episode reward:  -79.0 Episode:  437 Mean R -277.1014849678976
#
# Timestep:  67310 / 500000  Episode reward:  -45.0 Episode:  438 Mean R -274.54110863307733
#
# Timestep:  67442 / 500000  Episode reward:  -898.0 Episode:  439 Mean R -277.75722478554655
#
# Timestep:  67560 / 500000  Episode reward:  -442.0 Episode:  440 Mean R -281.0791768079284
#
# Timestep:  67651 / 500000  Episode reward:  -271.0 Episode:  441 Mean R -281.4703098027999
#
# Timestep:  67778 / 500000  Episode reward:  -411.0 Episode:  442 Mean R -283.02594930672285
#
# Timestep:  67898 / 500000  Episode reward:  -339.0 Episode:  443 Mean R -284.5442581114006
#
# Timestep:  68014 / 500000  Episode reward:  -243.0 Episode:  444 Mean R -284.2737413204293
#
# Timestep:  68105 / 500000  Episode reward:  -216.0 Episode:  445 Mean R -283.7765271074186
#
# Timestep:  68168 / 500000  Episode reward:  -215.0 Episode:  446 Mean R -283.2300199977833
#
# Timestep:  68241 / 500000  Episode reward:  -317.0 Episode:  447 Mean R -282.8180841187873
#
# Timestep:  68430 / 500000  Episode reward:  -331.0 Episode:  448 Mean R -283.1431183784833
#
# Timestep:  68546 / 500000  Episode reward:  -281.0 Episode:  449 Mean R -282.9137962799929
#
# Timestep:  68632 / 500000  Episode reward:  -194.0 Episode:  450 Mean R -283.69402523540396
#
# Timestep:  68699 / 500000  Episode reward:  -293.0 Episode:  451 Mean R -283.5356032809849
#
# Timestep:  68759 / 500000  Episode reward:  -175.0 Episode:  452 Mean R -282.0944895448178
#
# Timestep:  68866 / 500000  Episode reward:  -405.0 Episode:  453 Mean R -282.074237279405
#
# Timestep:  69012 / 500000  Episode reward:  -217.0 Episode:  454 Mean R -281.2327317195227
#
# Timestep:  69130 / 500000  Episode reward:  -94.0 Episode:  455 Mean R -280.5566914138169
#
# Timestep:  69287 / 500000  Episode reward:  -332.0 Episode:  456 Mean R -282.279202347979
#
# Timestep:  69444 / 500000  Episode reward:  -184.0 Episode:  457 Mean R -281.18177142728484
#
# Timestep:  69538 / 500000  Episode reward:  -240.0 Episode:  458 Mean R -279.211745736097
#
# Timestep:  69702 / 500000  Episode reward:  -310.0 Episode:  459 Mean R -279.562183445999
#
# Timestep:  69840 / 500000  Episode reward:  -507.0 Episode:  460 Mean R -279.1378060555076
#
# Timestep:  69946 / 500000  Episode reward:  -182.0 Episode:  461 Mean R -276.00350965128206
#
# Timestep:  70097 / 500000  Episode reward:  -195.0 Episode:  462 Mean R -276.3686661903161
#
# Timestep:  70221 / 500000  Episode reward:  -182.0 Episode:  463 Mean R -276.0467740456766
#
# Timestep:  70516 / 500000  Episode reward:  -118.0 Episode:  464 Mean R -273.9303904288029
#
# Timestep:  70987 / 500000  Episode reward:  -231.0 Episode:  465 Mean R -273.4481223776535
#
# Timestep:  71177 / 500000  Episode reward:  -212.0 Episode:  466 Mean R -272.12341007778343
#
# Timestep:  71496 / 500000  Episode reward:  -294.0 Episode:  467 Mean R -272.6617241921707
#
# Timestep:  71609 / 500000  Episode reward:  -271.0 Episode:  468 Mean R -273.5104209604201
#
# Timestep:  71737 / 500000  Episode reward:  -397.0 Episode:  469 Mean R -271.4211922846053
#
# Timestep:  71898 / 500000  Episode reward:  -179.0 Episode:  470 Mean R -268.7203855124387
#
# Timestep:  72000 / 500000  Episode reward:  -243.0 Episode:  471 Mean R -266.4427330826877
#
# Timestep:  72102 / 500000  Episode reward:  -486.0 Episode:  472 Mean R -268.89172308329915
#
# Timestep:  72378 / 500000  Episode reward:  -195.0 Episode:  473 Mean R -267.841738924513
#
# Timestep:  72534 / 500000  Episode reward:  -644.0 Episode:  474 Mean R -271.7590735130239
#
# Timestep:  72669 / 500000  Episode reward:  -282.0 Episode:  475 Mean R -271.67321786555766
#
# Timestep:  72788 / 500000  Episode reward:  -160.0 Episode:  476 Mean R -271.67766295854625
#
# Timestep:  72913 / 500000  Episode reward:  -302.0 Episode:  477 Mean R -271.66113726646
#
# Timestep:  73008 / 500000  Episode reward:  -919.0 Episode:  478 Mean R -278.2914399128078
#
# Timestep:  73149 / 500000  Episode reward:  -333.0 Episode:  479 Mean R -279.5869138296381
#
# Timestep:  73272 / 500000  Episode reward:  -204.0 Episode:  480 Mean R -279.4667216843026
#
# Timestep:  73501 / 500000  Episode reward:  -244.0 Episode:  481 Mean R -280.61834003334553
#
# Timestep:  73621 / 500000  Episode reward:  -264.0 Episode:  482 Mean R -279.4554480459728
#
# Timestep:  73756 / 500000  Episode reward:  -568.0 Episode:  483 Mean R -282.33477759740924
#
# Timestep:  73907 / 500000  Episode reward:  -350.0 Episode:  484 Mean R -282.3085514468098
#
# Timestep:  74106 / 500000  Episode reward:  -239.0 Episode:  485 Mean R -282.06781824649283
#
# Timestep:  74207 / 500000  Episode reward:  -272.0 Episode:  486 Mean R -281.99045870999106
#
# Timestep:  74301 / 500000  Episode reward:  -172.0 Episode:  487 Mean R -279.7538726083178
#
# Timestep:  74457 / 500000  Episode reward:  -210.0 Episode:  488 Mean R -279.7949766807093
#
# Timestep:  74605 / 500000  Episode reward:  -134.0 Episode:  489 Mean R -277.7340899417043
#
# Timestep:  74890 / 500000  Episode reward:  -140.0 Episode:  490 Mean R -273.72727525279987
#
# Timestep:  75049 / 500000  Episode reward:  -217.0 Episode:  491 Mean R -274.2060509500449
#
# Timestep:  75323 / 500000  Episode reward:  -163.0 Episode:  492 Mean R -273.7382398204964
#
# Timestep:  75503 / 500000  Episode reward:  -125.0 Episode:  493 Mean R -273.01974157827783
#
# Timestep:  75660 / 500000  Episode reward:  -149.0 Episode:  494 Mean R -269.3481259941903
#
# Timestep:  75779 / 500000  Episode reward:  -116.0 Episode:  495 Mean R -268.5830325882481
#
# Timestep:  75943 / 500000  Episode reward:  -317.0 Episode:  496 Mean R -267.9016290210741
#
# Timestep:  76090 / 500000  Episode reward:  -158.0 Episode:  497 Mean R -268.3571951568529
#
# Timestep:  76239 / 500000  Episode reward:  -407.0 Episode:  498 Mean R -270.6411417758684
#
# Timestep:  76407 / 500000  Episode reward:  -171.0 Episode:  499 Mean R -270.042373943145
#
# Timestep:  76486 / 500000  Episode reward:  -391.0 Episode:  500 Mean R -272.7914514993292
#
# Timestep:  76687 / 500000  Episode reward:  -174.0 Episode:  501 Mean R -270.8568723933028
#
# Timestep:  76830 / 500000  Episode reward:  -226.0 Episode:  502 Mean R -271.56613865328234
#
# Timestep:  76946 / 500000  Episode reward:  -255.0 Episode:  503 Mean R -272.3841010977895
#
# Timestep:  77051 / 500000  Episode reward:  -198.0 Episode:  504 Mean R -271.77957050402813
#
# Timestep:  77185 / 500000  Episode reward:  -270.0 Episode:  505 Mean R -271.87459754549457
#
# Timestep:  77299 / 500000  Episode reward:  -84.0 Episode:  506 Mean R -272.0258830939002
#
# Timestep:  77382 / 500000  Episode reward:  -284.0 Episode:  507 Mean R -272.46936204376647
#
# Timestep:  77488 / 500000  Episode reward:  -288.0 Episode:  508 Mean R -270.6618023806962
#
# Timestep:  77568 / 500000  Episode reward:  -9.0 Episode:  509 Mean R -269.1501735660646
#
# Timestep:  77637 / 500000  Episode reward:  -256.0 Episode:  510 Mean R -268.96234635416795
#
# Timestep:  77730 / 500000  Episode reward:  -450.0 Episode:  511 Mean R -270.39745962405084
#
# Timestep:  77807 / 500000  Episode reward:  -235.0 Episode:  512 Mean R -269.90527558025565
#
# Timestep:  77901 / 500000  Episode reward:  -10.0 Episode:  513 Mean R -269.3490349270802
#
# Timestep:  77973 / 500000  Episode reward:  -539.0 Episode:  514 Mean R -272.76899424725053
#
# Timestep:  78054 / 500000  Episode reward:  -230.0 Episode:  515 Mean R -272.5416823149543
#
# Timestep:  78140 / 500000  Episode reward:  -140.0 Episode:  516 Mean R -268.8593884037513
#
# Timestep:  78212 / 500000  Episode reward:  -154.0 Episode:  517 Mean R -268.6778999689021
#
# Timestep:  78281 / 500000  Episode reward:  -342.0 Episode:  518 Mean R -266.0245995272874
#
# Timestep:  78382 / 500000  Episode reward:  -210.0 Episode:  519 Mean R -265.9518150120229
#
# Timestep:  78638 / 500000  Episode reward:  -271.0 Episode:  520 Mean R -267.5310319517398
#
# Timestep:  78742 / 500000  Episode reward:  -405.0 Episode:  521 Mean R -267.20946889058206
#
# ...
#
# Timestep:  474207 / 500000  Episode reward:  -255.0 Episode:  3103 Mean R -266.00240297710485
#
# Timestep:  474364 / 500000  Episode reward:  -319.0 Episode:  3104 Mean R -267.18963597999726
#
# Timestep:  474499 / 500000  Episode reward:  -238.0 Episode:  3105 Mean R -265.80533306513905
#
# Timestep:  474633 / 500000  Episode reward:  -400.0 Episode:  3106 Mean R -269.3407061439045
#
# Timestep:  474804 / 500000  Episode reward:  -240.0 Episode:  3107 Mean R -268.4258385117777
#
# Timestep:  474971 / 500000  Episode reward:  -291.0 Episode:  3108 Mean R -269.78945961930657
#
# Timestep:  475097 / 500000  Episode reward:  -317.0 Episode:  3109 Mean R -271.93145514320685
#
# Timestep:  475172 / 500000  Episode reward:  -462.0 Episode:  3110 Mean R -274.1912974076885
#
# Timestep:  475337 / 500000  Episode reward:  -324.0 Episode:  3111 Mean R -272.70128736807754
#
# Timestep:  475694 / 500000  Episode reward:  -199.0 Episode:  3112 Mean R -272.5938588474485
#
# Timestep:  475905 / 500000  Episode reward:  -284.0 Episode:  3113 Mean R -274.4928558788486
#
# Timestep:  476027 / 500000  Episode reward:  -198.0 Episode:  3114 Mean R -274.98753574272195
#
# Timestep:  476158 / 500000  Episode reward:  -75.0 Episode:  3115 Mean R -271.53678125920356
#
# Timestep:  476292 / 500000  Episode reward:  -429.0 Episode:  3116 Mean R -273.7982168239604
#
# Timestep:  476376 / 500000  Episode reward:  -498.0 Episode:  3117 Mean R -276.0226677548106
#
# Timestep:  476488 / 500000  Episode reward:  -256.0 Episode:  3118 Mean R -278.8130317071757
#
# Timestep:  476604 / 500000  Episode reward:  -206.0 Episode:  3119 Mean R -278.8361265108336
#
# Timestep:  476780 / 500000  Episode reward:  -296.0 Episode:  3120 Mean R -280.62773280086094
#
# Timestep:  476886 / 500000  Episode reward:  -489.0 Episode:  3121 Mean R -281.37934127630257
#
# Timestep:  476963 / 500000  Episode reward:  -291.0 Episode:  3122 Mean R -282.8589503435801
#
# Timestep:  477150 / 500000  Episode reward:  -273.0 Episode:  3123 Mean R -284.96938858164583
#
# Timestep:  477227 / 500000  Episode reward:  -175.0 Episode:  3124 Mean R -285.207813420662
#
# Timestep:  477303 / 500000  Episode reward:  -243.0 Episode:  3125 Mean R -287.0049379545507
#
# Timestep:  477511 / 500000  Episode reward:  -390.0 Episode:  3126 Mean R -287.7784620428008
#
# Timestep:  477614 / 500000  Episode reward:  -295.0 Episode:  3127 Mean R -287.0801315833371
#
# Timestep:  477916 / 500000  Episode reward:  -293.0 Episode:  3128 Mean R -282.34823568348673
#
# Timestep:  478050 / 500000  Episode reward:  -239.0 Episode:  3129 Mean R -282.9069997274414
#
# Timestep:  478302 / 500000  Episode reward:  -114.0 Episode:  3130 Mean R -283.87598105251686
#
# Timestep:  478759 / 500000  Episode reward:  -257.0 Episode:  3131 Mean R -284.72910066910185
#
# Timestep:  478977 / 500000  Episode reward:  -189.0 Episode:  3132 Mean R -284.1655609965896
#
# Timestep:  479224 / 500000  Episode reward:  -199.0 Episode:  3133 Mean R -283.6546837706946
#
# Timestep:  479395 / 500000  Episode reward:  -417.0 Episode:  3134 Mean R -284.28386639000814
#
# Timestep:  479596 / 500000  Episode reward:  -233.0 Episode:  3135 Mean R -283.79541947925094
#
# Timestep:  479792 / 500000  Episode reward:  -289.0 Episode:  3136 Mean R -284.147962248364
#
# Timestep:  479898 / 500000  Episode reward:  -246.0 Episode:  3137 Mean R -280.60790581932304
#
# Timestep:  480033 / 500000  Episode reward:  -11.0 Episode:  3138 Mean R -279.02958017200444
#
# Timestep:  480213 / 500000  Episode reward:  -363.0 Episode:  3139 Mean R -279.05471449711604
#
# Timestep:  480423 / 500000  Episode reward:  -74.0 Episode:  3140 Mean R -277.1240327994512
#
# Timestep:  480644 / 500000  Episode reward:  -418.0 Episode:  3141 Mean R -280.1934801698843
#
# Timestep:  480837 / 500000  Episode reward:  -520.0 Episode:  3142 Mean R -278.29468886362616
#
# Timestep:  481062 / 500000  Episode reward:  -475.0 Episode:  3143 Mean R -281.79655704690043
#
# Timestep:  481222 / 500000  Episode reward:  -270.0 Episode:  3144 Mean R -280.5904498968178
#
# Timestep:  481306 / 500000  Episode reward:  -168.0 Episode:  3145 Mean R -280.4299611953659
#
# Timestep:  481445 / 500000  Episode reward:  -627.0 Episode:  3146 Mean R -282.766731051575
#
# Timestep:  481659 / 500000  Episode reward:  -393.0 Episode:  3147 Mean R -284.63139864377985
#
# Timestep:  481848 / 500000  Episode reward:  -248.0 Episode:  3148 Mean R -285.16456813780064
#
# Timestep:  481924 / 500000  Episode reward:  -196.0 Episode:  3149 Mean R -283.0041686231368
#
# Timestep:  482030 / 500000  Episode reward:  -582.0 Episode:  3150 Mean R -283.4168520879467
#
# Timestep:  482154 / 500000  Episode reward:  -139.0 Episode:  3151 Mean R -281.98470466608273
#
# Timestep:  482237 / 500000  Episode reward:  -47.0 Episode:  3152 Mean R -278.2394353357345
#
# Timestep:  482295 / 500000  Episode reward:  -219.0 Episode:  3153 Mean R -279.5539819436104
#
# Timestep:  482385 / 500000  Episode reward:  -354.0 Episode:  3154 Mean R -281.15413474989776
#
# Timestep:  482477 / 500000  Episode reward:  -132.0 Episode:  3155 Mean R -279.3606333665408
#
# Timestep:  482584 / 500000  Episode reward:  -463.0 Episode:  3156 Mean R -279.9681368579859
#
# Timestep:  482660 / 500000  Episode reward:  -215.0 Episode:  3157 Mean R -278.7027897237627
#
# Timestep:  482781 / 500000  Episode reward:  -26.0 Episode:  3158 Mean R -276.17377074608936
#
# Timestep:  482939 / 500000  Episode reward:  -308.0 Episode:  3159 Mean R -275.0053628877543
#
# Timestep:  483125 / 500000  Episode reward:  -236.0 Episode:  3160 Mean R -273.90284415437276
#
# Timestep:  483283 / 500000  Episode reward:  -577.0 Episode:  3161 Mean R -277.77595879111595
#
# Timestep:  483363 / 500000  Episode reward:  -617.0 Episode:  3162 Mean R -279.2925425614171
#
# Timestep:  483432 / 500000  Episode reward:  -141.0 Episode:  3163 Mean R -277.31926831911437
#
# Timestep:  483560 / 500000  Episode reward:  -305.0 Episode:  3164 Mean R -278.4269750807805
#
# Timestep:  483737 / 500000  Episode reward:  -330.0 Episode:  3165 Mean R -279.23021497276574
#
# Timestep:  483972 / 500000  Episode reward:  -147.0 Episode:  3166 Mean R -277.82260697662554
#
# Timestep:  484048 / 500000  Episode reward:  -143.0 Episode:  3167 Mean R -279.67658630575954
#
# Timestep:  484250 / 500000  Episode reward:  -510.0 Episode:  3168 Mean R -283.69402242565315
#
# Timestep:  484386 / 500000  Episode reward:  -252.0 Episode:  3169 Mean R -279.77822501887067
#
# Timestep:  484485 / 500000  Episode reward:  -292.0 Episode:  3170 Mean R -279.20304499592623
#
# Timestep:  484592 / 500000  Episode reward:  -153.0 Episode:  3171 Mean R -277.514277851462
#
# Timestep:  484718 / 500000  Episode reward:  -212.0 Episode:  3172 Mean R -278.65616573283984
#
# Timestep:  484836 / 500000  Episode reward:  -153.0 Episode:  3173 Mean R -278.35746833893734
#
# Timestep:  485016 / 500000  Episode reward:  -327.0 Episode:  3174 Mean R -278.10091169706334
#
# Timestep:  485136 / 500000  Episode reward:  -611.0 Episode:  3175 Mean R -283.78811199923535
#
# Timestep:  485387 / 500000  Episode reward:  -229.0 Episode:  3176 Mean R -284.3905057336218
#
# Timestep:  485529 / 500000  Episode reward:  -310.0 Episode:  3177 Mean R -285.90931861619714
#
# Timestep:  485689 / 500000  Episode reward:  -252.0 Episode:  3178 Mean R -286.98218794993426
#
# Timestep:  485782 / 500000  Episode reward:  -538.0 Episode:  3179 Mean R -287.83518868621866
#
# Timestep:  486033 / 500000  Episode reward:  -407.0 Episode:  3180 Mean R -287.9392803385126
#
# Timestep:  486172 / 500000  Episode reward:  -97.0 Episode:  3181 Mean R -286.05192383796765
#
# Timestep:  486406 / 500000  Episode reward:  -370.0 Episode:  3182 Mean R -285.2827506331267
#
# Timestep:  486648 / 500000  Episode reward:  -283.0 Episode:  3183 Mean R -284.505228491335
#
# Timestep:  486794 / 500000  Episode reward:  -380.0 Episode:  3184 Mean R -284.7346394147576
#
# Timestep:  486895 / 500000  Episode reward:  -546.0 Episode:  3185 Mean R -286.7874665331638
#
# Timestep:  486993 / 500000  Episode reward:  -246.0 Episode:  3186 Mean R -286.3559659417845
#
# Timestep:  487122 / 500000  Episode reward:  -184.0 Episode:  3187 Mean R -287.7562978816731
#
# Timestep:  487234 / 500000  Episode reward:  -243.0 Episode:  3188 Mean R -286.73388385179874
#
# Timestep:  487363 / 500000  Episode reward:  -292.0 Episode:  3189 Mean R -288.3375790278591
#
# Timestep:  487580 / 500000  Episode reward:  16.0 Episode:  3190 Mean R -286.22125298569483
#
# Timestep:  487655 / 500000  Episode reward:  -220.0 Episode:  3191 Mean R -284.4876889078871
#
# Timestep:  487800 / 500000  Episode reward:  -204.0 Episode:  3192 Mean R -284.556662816699
#
# Timestep:  487933 / 500000  Episode reward:  -87.0 Episode:  3193 Mean R -285.15339027566006
#
# Timestep:  488032 / 500000  Episode reward:  -429.0 Episode:  3194 Mean R -287.4881657361208
#
# Timestep:  488231 / 500000  Episode reward:  -297.0 Episode:  3195 Mean R -287.4808576941661
#
# Timestep:  488402 / 500000  Episode reward:  -220.0 Episode:  3196 Mean R -286.6046289729387
#
# Timestep:  488549 / 500000  Episode reward:  -146.0 Episode:  3197 Mean R -285.15014501760356
#
# Timestep:  488743 / 500000  Episode reward:  -12.0 Episode:  3198 Mean R -282.9534540013218
#
# Timestep:  488868 / 500000  Episode reward:  -217.0 Episode:  3199 Mean R -282.46493508254173
#
# Timestep:  488975 / 500000  Episode reward:  -193.0 Episode:  3200 Mean R -281.26159848553687
#
# Timestep:  489195 / 500000  Episode reward:  -316.0 Episode:  3201 Mean R -280.32666623838577
#
# Timestep:  489301 / 500000  Episode reward:  -318.0 Episode:  3202 Mean R -281.8824894463733
#
# Timestep:  489389 / 500000  Episode reward:  -377.0 Episode:  3203 Mean R -283.1030648694793
#
# Timestep:  489748 / 500000  Episode reward:  -446.0 Episode:  3204 Mean R -284.3731191511849
#
# Timestep:  489841 / 500000  Episode reward:  -334.0 Episode:  3205 Mean R -285.3393226895187
#
# Timestep:  490108 / 500000  Episode reward:  -424.0 Episode:  3206 Mean R -285.5777961967365
#
# Timestep:  490198 / 500000  Episode reward:  -357.0 Episode:  3207 Mean R -286.7474459456063
#
# Timestep:  490282 / 500000  Episode reward:  -695.0 Episode:  3208 Mean R -290.793491717431
#
# Timestep:  490372 / 500000  Episode reward:  -131.0 Episode:  3209 Mean R -288.93806246925425
#
# Timestep:  490506 / 500000  Episode reward:  -517.0 Episode:  3210 Mean R -289.4884690746076
#
# Timestep:  490587 / 500000  Episode reward:  -229.0 Episode:  3211 Mean R -288.54467441616407
#
# Timestep:  490816 / 500000  Episode reward:  -465.0 Episode:  3212 Mean R -291.20898672514835
#
# Timestep:  490905 / 500000  Episode reward:  -201.0 Episode:  3213 Mean R -290.3792564608214
#
# Timestep:  491007 / 500000  Episode reward:  -379.0 Episode:  3214 Mean R -292.19032363213523
#
# Timestep:  491097 / 500000  Episode reward:  -285.0 Episode:  3215 Mean R -294.2881641784914
#
# Timestep:  491200 / 500000  Episode reward:  -300.0 Episode:  3216 Mean R -292.9971520849395
#
# Timestep:  491363 / 500000  Episode reward:  -406.0 Episode:  3217 Mean R -292.0742677200171
#
# Timestep:  491805 / 500000  Episode reward:  -393.0 Episode:  3218 Mean R -293.4500516109267
#
# Timestep:  491931 / 500000  Episode reward:  -345.0 Episode:  3219 Mean R -294.8425116508172
#
# Timestep:  492094 / 500000  Episode reward:  -96.0 Episode:  3220 Mean R -292.84086830506976
#
# Timestep:  492235 / 500000  Episode reward:  -124.0 Episode:  3221 Mean R -289.18750328419975
#
# Timestep:  492412 / 500000  Episode reward:  -123.0 Episode:  3222 Mean R -287.50170518590176
#
# Timestep:  492653 / 500000  Episode reward:  -171.0 Episode:  3223 Mean R -286.4889223645351
#
# Timestep:  492887 / 500000  Episode reward:  -262.0 Episode:  3224 Mean R -287.3580635951104
#
# Timestep:  492999 / 500000  Episode reward:  -511.0 Episode:  3225 Mean R -290.0338294375853
#
# Timestep:  493101 / 500000  Episode reward:  -242.0 Episode:  3226 Mean R -288.5532618807635
#
# Timestep:  493212 / 500000  Episode reward:  -639.0 Episode:  3227 Mean R -291.9919125359242
#
# Timestep:  493318 / 500000  Episode reward:  -250.0 Episode:  3228 Mean R -291.5576471009724
#
# Timestep:  493416 / 500000  Episode reward:  -146.0 Episode:  3229 Mean R -290.6215386591645
#
# Timestep:  493534 / 500000  Episode reward:  -398.0 Episode:  3230 Mean R -293.46461558984066
#
# Timestep:  493622 / 500000  Episode reward:  -46.0 Episode:  3231 Mean R -291.3487677658874
#
# Timestep:  493698 / 500000  Episode reward:  -102.0 Episode:  3232 Mean R -290.4820259646783
#
# Timestep:  493790 / 500000  Episode reward:  -467.0 Episode:  3233 Mean R -293.15565116566125
#
# Timestep:  493901 / 500000  Episode reward:  -200.0 Episode:  3234 Mean R -290.9857818438814
#
# Timestep:  494007 / 500000  Episode reward:  -172.0 Episode:  3235 Mean R -290.3848351069837
#
# Timestep:  494094 / 500000  Episode reward:  -206.0 Episode:  3236 Mean R -289.5550842027232
#
# Timestep:  494190 / 500000  Episode reward:  -448.0 Episode:  3237 Mean R -291.5768133023145
#
# Timestep:  494421 / 500000  Episode reward:  -235.0 Episode:  3238 Mean R -293.81516333102974
#
# Timestep:  494696 / 500000  Episode reward:  -368.0 Episode:  3239 Mean R -293.8703004943216
#
# Timestep:  494872 / 500000  Episode reward:  -192.0 Episode:  3240 Mean R -295.05112251354046
#
# Timestep:  494975 / 500000  Episode reward:  -293.0 Episode:  3241 Mean R -293.7979697370873
#
# Timestep:  495204 / 500000  Episode reward:  -281.0 Episode:  3242 Mean R -291.4130564975518
#
# Timestep:  495318 / 500000  Episode reward:  -214.0 Episode:  3243 Mean R -288.8018908159954
#
# Timestep:  495465 / 500000  Episode reward:  -210.0 Episode:  3244 Mean R -288.2100132101172
#
# Timestep:  495581 / 500000  Episode reward:  -279.0 Episode:  3245 Mean R -289.31890189726477
#
# Timestep:  495727 / 500000  Episode reward:  -164.0 Episode:  3246 Mean R -284.6914152481543
#
# Timestep:  495841 / 500000  Episode reward:  -163.0 Episode:  3247 Mean R -282.39420773205035
#
# Timestep:  496012 / 500000  Episode reward:  -958.0 Episode:  3248 Mean R -289.4946637927592
#
# Timestep:  496137 / 500000  Episode reward:  -269.0 Episode:  3249 Mean R -290.2286949476699
#
# Timestep:  496269 / 500000  Episode reward:  -369.0 Episode:  3250 Mean R -288.09171793331626
#
# Timestep:  496486 / 500000  Episode reward:  -53.0 Episode:  3251 Mean R -287.22699318133124
#
# Timestep:  496604 / 500000  Episode reward:  -67.0 Episode:  3252 Mean R -287.42280647610283
#
# Timestep:  496745 / 500000  Episode reward:  -118.0 Episode:  3253 Mean R -286.41205185554605
#
# Timestep:  496938 / 500000  Episode reward:  -294.0 Episode:  3254 Mean R -285.8078864435088
#
# Timestep:  497072 / 500000  Episode reward:  -243.0 Episode:  3255 Mean R -286.9173573147589
#
# Timestep:  497270 / 500000  Episode reward:  -210.0 Episode:  3256 Mean R -284.3827571655324
#
# Timestep:  497540 / 500000  Episode reward:  -182.0 Episode:  3257 Mean R -284.0514305549001
#
# Timestep:  497763 / 500000  Episode reward:  -271.0 Episode:  3258 Mean R -286.50728437282885
#
# Timestep:  497873 / 500000  Episode reward:  -185.0 Episode:  3259 Mean R -285.27851609884857
#
# Timestep:  498073 / 500000  Episode reward:  -434.0 Episode:  3260 Mean R -287.2648068372299
#
# Timestep:  498318 / 500000  Episode reward:  -367.0 Episode:  3261 Mean R -285.16946965407755
#
# Timestep:  498447 / 500000  Episode reward:  -192.0 Episode:  3262 Mean R -280.9185410043044
#
# Timestep:  498579 / 500000  Episode reward:  -241.0 Episode:  3263 Mean R -281.91727788066146
#
# Timestep:  498694 / 500000  Episode reward:  -290.0 Episode:  3264 Mean R -281.76948651048673
#
# Timestep:  498762 / 500000  Episode reward:  -31.0 Episode:  3265 Mean R -278.77259913665705
#
# Timestep:  498901 / 500000  Episode reward:  -306.0 Episode:  3266 Mean R -280.363265106001
#
# Timestep:  499080 / 500000  Episode reward:  -158.0 Episode:  3267 Mean R -280.51955114765343
#
# Timestep:  499176 / 500000  Episode reward:  -167.0 Episode:  3268 Mean R -277.0927754732791
#
# Timestep:  499530 / 500000  Episode reward:  -347.0 Episode:  3269 Mean R -278.04855869520765
#
# Timestep:  499734 / 500000  Episode reward:  -190.0 Episode:  3270 Mean R -277.0274886970285
#
# Timestep:  499911 / 500000  Episode reward:  -247.0 Episode:  3271 Mean R -277.9724872606392
# Figure(640x480)

# %%
# !python TD3.py
